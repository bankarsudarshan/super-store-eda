# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('./SuperStore_Dataset.csv')
df.shape
# Out:
# (10014, 21)

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales Price      float64
# Quantity         float64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales Price', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.rename(columns={
    'Row ID':'row_id',
    'Order ID':'order_id', 
    'Order Date':'order_date', 
    'Ship Date':'ship_date',
    'Ship Mode':'ship_mode',
    'Customer ID':'customer_id',
    'Customer Name':'customer_name',
    'Segment':'segment',
    'Country':'country',
    'City':'city', 
    'State':'state',
    'Postal Code':'postal_code',
    'Region':'region',
    'Product ID':'product_id', 
    'Category':'category',
    'Sub-Category':'sub_category',
    'Product Name':'product_name',
    'Sales Price':'sales_price',
    'Quantity':'quantity',
    'Discount':'discount',
    'Profit':'profit'
}, inplace=True)

# %%
df.head(10)
# Out:
#    row_id        order_id order_date  ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156   08/11/16   11/11/16    Second Class    CG-12520
# 1       2  CA-2016-152156   08/11/16   11/11/16    Second Class    CG-12520
# 2       3  CA-2016-138688   12/06/16   16/06/16    Second Class    DV-13045
# 3       4  US-2015-108966   11/10/15   18/10/15  Standard Class    SO-20335
# 4       5  US-2015-108966   11/10/15   18/10/15  Standard Class    SO-20335
# 5       6  CA-2014-115812   09/06/14  2014-6-14  Standard Class    BH-11710
# 6       7  CA-2014-115812   09/06/14  2014-6-14  Standard Class    BH-11710
# 7       8  CA-2014-115812   09/06/14  2014-6-14  Standard Class    BH-11710
# 8       9  CA-2014-115812   09/06/14  2014-6-14  Standard Class    BH-11710
# 9      10  CA-2014-115812   09/06/14  2014-6-14  Standard Class    BH-11710
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  California
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  California
# 7  Brosina Hoffman   Consumer  United States      Los Angeles  California
# 8  Brosina Hoffman   Consumer  United States      Los Angeles  California
# 9  Brosina Hoffman   Consumer  United States      Los Angeles  California
#
#    postal_code region       product_id         category sub_category  \
# 0        42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1        42420  South  FUR-CH-10000454        Furniture       Chairs
# 2        90036   West  OFF-LA-10000240  Office Supplies       Labels
# 3        33311  South  FUR-TA-10000577        Furniture       Tables
# 4        33311  South  OFF-ST-10000760  Office Supplies      Storage
# 5        90032   West  FUR-FU-10001487        Furniture  Furnishings
# 6        90032   West  OFF-AR-10002833  Office Supplies          Art
# 7        90032   West  TEC-PH-10002275       Technology       Phones
# 8        90032   West  OFF-BI-10003910  Office Supplies      Binders
# 9        90032   West  OFF-AP-10002892  Office Supplies   Appliances
#
#                                         product_name  sales_price  quantity  \
# 0                  Bush Somerset Collection Bookcase     261.9600       2.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400       3.0
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200       2.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775       5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680       2.0
# 5  Eldon Expressions Wood and Plastic Desk Access...      48.8600       7.0
# 6                                         Newell 322       7.2800       4.0
# 7                     Mitel 5320 IP Phone VoIP phone     907.1520       6.0
# 8  DXL Angle-View Binders with Locking Rings by S...      18.5040       3.0
# 9                   Belkin F5C206VTEL 6 Outlet Surge     114.9000       5.0
#
#    discount    profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
# 5      0.00   14.1694
# 6      0.00    1.9656
# 7      0.20   90.7152
# 8      0.20    5.7825
# 9      0.00   34.4700

# %%
df.tail(10)
# Out:
#        row_id        order_id order_date   ship_date       ship_mode  \
# 10004    1043  CA-2016-102981   06/09/16    09/09/16    Second Class
# 10005    1044  CA-2017-115651   09/07/17    12/07/17     First Class
# 10006    1045  CA-2017-115651   09/07/17    12/07/17     First Class
# 10007    1046  CA-2017-152702   12/10/17    16/10/17  Standard Class
# 10008    1047  CA-2016-169103   08/03/16    13/03/16  Standard Class
# 10009    1048  CA-2016-169103   08/03/16    13/03/16  Standard Class
# 10010    9613  CA-2016-110086   18/09/16    22/09/16  Standard Class
# 10011    9614  CA-2014-128524   11/11/14  2014-11-13     First Class
# 10012    9615  CA-2014-128524   11/11/14  2014-11-13     First Class
# 10013    9616  CA-2014-128524   11/11/14  2014-11-13     First Class
#
#       customer_id     customer_name      segment        country  \
# 10004    MO-17500     Mary O'Rourke     Consumer  United States
# 10005    NS-18640      Noel Staavos    Corporate  United States
# 10006    NS-18640      Noel Staavos    Corporate  United States
# 10007    SN-20710      Steve Nguyen  Home Office  United States
# 10008    ZC-21910  Zuschuss Carroll     Consumer  United States
# 10009    ZC-21910  Zuschuss Carroll     Consumer  United States
# 10010    BD-11320    Bill Donatelli     Consumer  United States
# 10011    MZ-17515         Mary Zewe    Corporate  United States
# 10012    MZ-17515         Mary Zewe    Corporate  United States
# 10013    MZ-17515         Mary Zewe    Corporate  United States
#
#                 city       state  postal_code   region       product_id  \
# 10004  New York City    New York        10035     East  FUR-BO-10001811
# 10005        Chicago    Illinois        60610  Central  OFF-AR-10001130
# 10006        Chicago    Illinois        60610  Central  OFF-AP-10000055
# 10007       Rockford    Illinois        61107  Central  FUR-CH-10002304
# 10008          Miami     Florida        33142    South  TEC-PH-10001530
# 10009          Miami     Florida        33142    South  FUR-FU-10004006
# 10010       Woodland  California        95695     West  TEC-PH-10001299
# 10011        Seattle  Washington        98115     West  OFF-AP-10002892
# 10012        Seattle  Washington        98115     West  TEC-AC-10002718
# 10013        Seattle  Washington        98115     West  OFF-BI-10003527
#
#               category sub_category  \
# 10004        Furniture    Bookcases
# 10005  Office Supplies          Art
# 10006  Office Supplies   Appliances
# 10007        Furniture       Chairs
# 10008       Technology       Phones
# 10009        Furniture  Furnishings
# 10010       Technology       Phones
# 10011  Office Supplies   Appliances
# 10012       Technology  Accessories
# 10013  Office Supplies      Binders
#
#                                             product_name  sales_price  \
# 10004  Atlantic Metals Mobile 5-Shelf Bookcases, Cust...      722.352
# 10005                 Quartet Alpha White Chalk, 12/Pack       -8.840
# 10006                    Belkin F9S820V06 8 Outlet Surge       58.464
# 10007             Global Stack Chair without Arms, Black      254.604
# 10008            Cisco Unified IP Phone 7945G VoIP phone     1363.960
# 10009  Deflect-o DuraMat Lighweight, Studded, Beveled...      102.360
# 10010         Polycom CX300 Desktop Phone USB VoIP phone      239.984
# 10011                   Belkin F5C206VTEL 6 Outlet Surge       22.980
# 10012               Belkin Standard 104 key USB Keyboard      102.130
# 10013  Fellowes PB500 Electric Punch Plastic Comb Bin...     2033.584
#
#        quantity  discount    profit
# 10004       3.0       0.2   90.2940
# 10005       5.0       0.2    2.9835
# 10006       9.0       0.8 -146.1600
# 10007      14.0       0.3  -18.1860
# 10008       5.0       0.2   85.2475
# 10009       3.0       0.2   -3.8385
# 10010       2.0       0.2   23.9984
# 10011       1.0       0.0    6.8940
# 10012       7.0       0.0   15.3195
# 10013       2.0       0.2  762.5940

# %% [markdown]
# ## 2. Handling Duplicates

# %%
duplicate_rows_mask = df.duplicated()
df.loc[duplicate_rows_mask]
# Out:
#        row_id        order_id order_date   ship_date       ship_mode  \
# 9994     9980  US-2016-103674   06/12/16    10/12/16  Standard Class
# 9995     9981  US-2015-151435   06/09/15    09/09/15    Second Class
# 9996       18  CA-2014-167164   13/05/14   2014-5-15    Second Class
# 9997       19  CA-2014-143336   27/08/14    2014-9-1    Second Class
# 9999       21  CA-2014-143336   27/08/14    2014-9-1    Second Class
# 10001    8853  CA-2014-119977   08/10/14  2014-10-13    Second Class
# 10002    8854  US-2015-115343   22/09/15    25/09/15     First Class
# 10003       Technology  Accessories
# 10004        Furniture    Bookcases
# 10006  Office Supplies   Appliances
# 10007        Furniture       Chairs
# 10008       Technology       Phones
# 10009        Furniture  Furnishings
# 10010       Technology       Phones
# 10011  Office Supplies   Appliances
# 10012       Technology  Accessories
# 10013  Office Supplies      Binders
#
#                                             product_name  sales_price  \
# 9994                   Ibico Recycled Linen-Style Covers      437.472
# 9995                          KI Adjustable-Height Table       85.980
# 9996                          Fellowes Super Stor/Drawer       55.500
# 9997                                          Newell 341        8.560
# 9999         Wilson Jones Hanging View Binder, White, 1"       22.720
# 10001                                          Xerox 197      123.920
# 10002  Acme Hot Forged Carbon Steel Scissors with Nic...       55.600
# 10003                 Logitech�P710e Mobile Speakerphone      617.976
# 10004  Atlantic Metals Mobile 5-Shelf Bookcases, Cust...      722.352
# 10006                    Belkin F9S820V06 8 Outlet Surge       58.464
# 10007             Global Stack Chair without Arms, Black      254.604
# 10008            Cisco Unified IP Phone 7945G VoIP phone     1363.960
# 10009  Deflect-o DuraMat Lighweight, Studded, Beveled...      102.360
# 10010         Polycom CX300 Desktop Phone USB VoIP phone      239.984
# 10011                   Belkin F5C206VTEL 6 Outlet Surge       22.980
# 10012               Belkin Standard 104 key USB Keyboard      102.130
# 10013  Fellowes PB500 Electric Punch Plastic Comb Bin...     2033.584
#
#        quantity  discount    profit
# 9994       14.0       0.2  153.1152
# 9995        1.0       0.0   22.3548
# 9996        2.0       0.0    9.9900
# 9997        2.0       0.0    2.4824
# 9999        4.0       0.2    7.3840
# 10001       4.0       0.0   55.7640
# 10002       5.0       0.2    6.2550
# 10003       3.0       0.2   -7.7247
# 10004       3.0       0.2   90.2940
# 10006       9.0       0.8 -146.1600
# 10007      14.0       0.3  -18.1860
# 10008       5.0       0.2   85.2475
# 10009       3.0       0.2   -3.8385
# 10010       2.0       0.2   23.9984
# 10011       1.0       0.0    6.8940
# 10012       7.0       0.0   15.3195
# 10013       2.0       0.2  762.5940

# %%
duplicate_rowIDs_mask = df.duplicated(['row_id'])
print(f'Number of duplicate (entire) rows are - {len( df.loc[duplicate_rows_mask] )}')
print(f'Number of rows with duplicate row_id attribute are - {len( df.loc[duplicate_rowIDs_mask] )}')
# Out:
# Number of duplicate (entire) rows are - 17
# Number of rows with duplicate row_id attribute are - 20

# %% [markdown]
# - There are **3 rows** with duplicate `row_id` attribute
# - So, let's check the differences in duplicated rows by:
#   - <ins>keeping first rows</ins> and marking the last as duplicates
#   - and then <ins>keeping last rows</ins> and marking the first as the rows with duplicate row_ids.

# %%
df.loc[ duplicate_rowIDs_mask & ~duplicate_rows_mask ]
# Out:
#        row_id        order_id order_date ship_date     ship_mode customer_id  \
# 9998       20  CA-2014-143336   27/08/14  2014-9-1  Second Class    ZD-21925
# 10000    8852  CA-2015-140718   02/07/15  04/07/15   First Class    FA-14230
# 10005    1044  CA-2017-115651   09/07/17  12/07/17   First Class    NS-18640
#
#             customer_name    segment        country           city  \
# 9998   Zuschuss Donatelli   Consumer  United States  San Francisco
# 10000      Frank Atkinson  Corporate  United States        Raleigh
# 10005        Noel Staavos  Corporate  United States        Chicago
#
#                 state  postal_code   region       product_id         category  \
# 9998       California        94109     West  TEC-PH-10001949       Technology
# 10000  North Carolina        27604    South  OFF-PA-10002250  Office Supplies
# 10005        Illinois        60610  Central  OFF-AR-10001130  Office Supplies
#
#       sub_category                        product_name  sales_price  quantity  \
# 9998        Phones             Cisco SPA 501G IP Phone      213.480       3.0
# 10000        Paper              Things To Do Today Pad       -9.392       2.0
# 10005          Art  Quartet Alpha White Chalk, 12/Pack       -8.840       5.0
#
#        discount   profit
# 9998        0.2  16.0110
# 10000       0.2   3.2872
# 10005       0.2   2.9835

# %%
duplicate_rows_mask2 = df.duplicated(keep='last')
duplicate_rowIDs_mask2 = df.duplicated(['row_id'], keep='last')
df.loc[ duplicate_rowIDs_mask2 & ~duplicate_rows_mask2 ]
# Out:
#       row_id        order_id order_date ship_date     ship_mode customer_id  \
# 19        20  CA-2014-143336   27/08/14  2014-9-1  Second Class    ZD-21925
# 1043    1044  CA-2017-115651   09/07/17  12/07/17   First Class    NS-18640
# 8851    8852  CA-2015-140718   02/07/15  04/07/15   First Class    FA-14230
#
#            customer_name    segment        country           city  \
# 19    Zuschuss Donatelli   Consumer  United States  San Francisco
# 1043        Noel Staavos  Corporate  United States        Chicago
# 8851      Frank Atkinson  Corporate  United States        Raleigh
#
#                state  postal_code   region       product_id         category  \
# 19        California        94109     West  TEC-PH-10001949       Technology
# 1043        Illinois        60610  Central  OFF-AR-10001130  Office Supplies
# 8851  North Carolina        27604    South  OFF-PA-10002250  Office Supplies
#
#      sub_category                        product_name  sales_price  quantity  \
# 19         Phones             Cisco SPA 501G IP Phone      213.480       NaN
# 1043          Art  Quartet Alpha White Chalk, 12/Pack        8.840       5.0
# 8851        Paper              Things To Do Today Pad        9.392       2.0
#
#       discount   profit
# 19         0.2  16.0110
# 1043       0.2   2.9835
# 8851       0.2   3.2872

# %% [markdown]
# - Row 9998 and 19 are the same with the differences in `quantity` column. row-19 contains the quatity as NaN while 9998 has a defined quantity. Therefore keeping row 9998.
# - Rows '10000 & 8851' and '10005 & 1043' are same except they have a sign's difference in the `sales_price` column(1043 and 8851 have -ve sales_price).

# %% [markdown]
# - do other rows with -ve `sales_price` exist?
#   - if yes, then does that indicate a sale in loss
# - if they do, then do -ve `profit`s also exist?

# %%
neg_sales_prices = df.loc[ df['sales_price'] < 0 ]
neg_sales_prices
# Out:
#        row_id        order_id order_date  ship_date       ship_mode  \
# 9794     9795  CA-2014-127166   21/05/14  2014-5-23    Second Class
# 9984     9985  CA-2015-100251   17/05/15   23/05/15  Standard Class
# 10000    8852  CA-2015-140718   02/07/15   04/07/15     First Class
# 10005    1044  CA-2017-115651   09/07/17   12/07/17     First Class
#
#       customer_id     customer_name    segment        country        city  \
# 9794     KH-16360  Katherine Hughes   Consumer  United States     Houston
# 9984     DV-13465  Dianna Vittorini   Consumer  United States  Long Beach
# 10000    FA-14230    Frank Atkinson  Corporate  United States     Raleigh
# 10005    NS-18640      Noel Staavos  Corporate  United States     Chicago
#
#                 state  postal_code   region       product_id         category  \
# 9794               TX        77070  Central  OFF-BI-10000977  Office Supplies
# 9984               NY        11561     East  OFF-LA-10003766  Office Supplies
# 10000  North Carolina        27604    South  OFF-PA-10002250  Office Supplies
# 10005        Illinois        60610  Central  OFF-AR-10001130  Office Supplies
#
#       sub_category                        product_name  sales_price  quantity  \
# 9794       Binders  Ibico Plastic Spiral Binding Combs      -18.240       3.0
# 9984        Labels      Self-Adhesive Removable Labels      -31.500      10.0
# 10000        Paper              Things To Do Today Pad       -9.392       2.0
# 10005          Art  Quartet Alpha White Chalk, 12/Pack       -8.840       5.0
#
#        discount   profit
# 9794        0.8 -31.0080
# 9984        0.0  15.1200
# 10000       0.2   3.2872
# 10005       0.2   2.9835

# %% [markdown]
# - so there are two more rows with negative sales_price
# - out of the 4 rows with negative sales price, only 1 has a negative profit

# %%
# confirming if -ve profits are a result of -ve sales_price
df.loc[ df['profit'] < 0 ]
# Out:
#        row_id        order_id order_date ship_date       ship_mode  \
# 3           4  US-2015-108966   11/10/15  18/10/15  Standard Class
# 14         15  US-2015-118983   22/11/15  26/11/15  Standard Class
# 15         16  US-2015-118983   22/11/15  26/11/15  Standard Class
# 23         24  US-2017-156909   16/07/17  18/07/17    Second Class
# 27         28  US-2015-150630   17/09/15  21/09/15  Standard Class
# ...       ...             ...        ...       ...             ...
# 9962     9963  CA-2015-168088   19/03/15  22/03/15     First Class
# 10003    8855  US-2015-115343   22/09/15  25/09/15     First Class
# 10006    1045  CA-2017-115651   09/07/17  12/07/17     First Class
# 10007    1046  CA-2017-152702   12/10/17  16/10/17  Standard Class
# 10009    1048  CA-2016-169103   08/03/16  13/03/16  Standard Class
#
#       customer_id     customer_name      segment        country  \
# 3        SO-20335    Sean O'Donnell     Consumer  United States
# 14       HP-14815     Harold Pawlan  Home Office  United States
# 15       HP-14815     Harold Pawlan  Home Office  United States
# 23       SF-20065   Sandra Flanagan     Consumer  United States
# 27       TB-21520   Tracy Blumstein     Consumer  United States
# ...           ...               ...          ...            ...
# 9962     CM-12655  Corinna Mitchell  Home Office  United States
# 10003    FO-14305       Frank Olsen     Consumer  United States
# 10006    NS-18640      Noel Staavos    Corporate  United States
# 10007    SN-20710      Steve Nguyen  Home Office  United States
# 10009    ZC-21910  Zuschuss Carroll     Consumer  United States
#
#                   city         state  postal_code   region       product_id  \
# 3      Fort Lauderdale       Florida        33311    South  FUR-TA-10000577
# 14          Fort Worth         Texas        76106  Central  OFF-AP-10002311
# 15          Fort Worth         Texas        76106  Central  OFF-BI-10000756
# 23        Philadelphia  Pennsylvania        19140     East  FUR-CH-10002774
# 27        Philadelphia  Pennsylvania        19140     East  FUR-BO-10004834
# ...                ...           ...          ...      ...              ...
# 9962           Houston         Texas        77041  Central  FUR-BO-10004218
# 10003     Philadelphia  Pennsylvania        19143     East  TEC-AC-10003832
# 10006          Chicago      Illinois        60610  Central  OFF-AP-10000055
# 10007         Rockford      Illinois        61107  Central  FUR-CH-10002304
# 10009            Miami       Florida        33142    South  FUR-FU-10004006
#
#               category sub_category  \
# 3            Furniture       Tables
# 14     Office Supplies   Appliances
# 15     Office Supplies      Binders
# 23           Furniture       Chairs
# 27           Furniture    Bookcases
# ...                ...          ...
# 9962         Furniture    Bookcases
# 10003       Technology  Accessories
# 10006  Office Supplies   Appliances
# 10007        Furniture       Chairs
# 10009        Furniture  Furnishings
#
#                                             product_name  sales_price  \
# 3          Bretford CR4500 Series Slim Rectangular Table     957.5775
# 14     Holmes Replacement Filter for HEPA Air Cleaner...      68.8100
# 15      Storex DuraTech Recycled Plastic Frosted Binders       2.5440
# 23                    Global Deluxe Stacking Chair, Gray      71.3720
# 27     Riverside Palais Royal Lawyers Bookcase, Royal...    3083.4300
# ...                                                  ...          ...
# 9962   Bush Heritage Pine Collection 5-Shelf Bookcase...     383.4656
# 10003                 Logitech�P710e Mobile Speakerphone     617.9760
# 10006                    Belkin F9S820V06 8 Outlet Surge      58.4640
# 10007             Global Stack Chair without Arms, Black     254.6040
# 10009  Deflect-o DuraMat Lighweight, Studded, Beveled...     102.3600
#
#        quantity  discount     profit
# 3           5.0      0.45  -383.0310
# 14          5.0      0.80  -123.8580
# 15          NaN      0.80    -3.8160
# 23          2.0      0.30    -1.0196
# 27          7.0      0.50 -1665.0522
# ...         ...       ...        ...
# 9962        4.0      0.32   -67.6704
# 10003       3.0      0.20    -7.7247
# 10006       9.0      0.80  -146.1600
# 10007      14.0      0.30   -18.1860
# 10009       3.0      0.20    -3.8385
#
# [1875 rows x 21 columns]

# %% [markdown]
# #### Thus, a -ve sales_price does not indicate a sale in loss (-ve profit). The 4 rows with -ve sales are just accidental wrong data entries

# %%
df['sales_price'] = np.abs(df['sales_price'])

# %%
neg_sales_prices = df.loc[ df['sales_price'] < 0 ]
neg_sales_prices
# Out:
# Empty DataFrame
# Columns: [row_id, order_id, order_date, ship_date, ship_mode, customer_id, customer_name, segment, country, city, state, postal_code, region, product_id, category, sub_category, product_name, sales_price, quantity, discount, profit]
# Index: []

# %%
df.shape
# Out:
# (10014, 21)

# %%
labels_to_drop = list(df.loc[mask].index)
labels_to_drop.append(19)
labels_to_drop.append(10000)
labels_to_drop.append(10005)
df.drop(labels_to_drop, axis='index', inplace=True)
df.shape
# Out:
# (9994, 21)

# %% [markdown]
# - Dropping the row_id column as its need is sufficed
# - The dataframe index maintains a unique row number for each row same as row_id column

# %%
df.drop(['row_id'], axis='columns', inplace=True)

# %%
# do duplicate rows still exist?
duplicate_rows_mask = df.duplicated()
df[duplicate_rows_mask]
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 3406  US-2014-150119   23/04/14  2014-4-27  Standard Class    LB-16795
#
#        customer_name      segment        country      city state  postal_code  \
# 3406  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
#
#      region       product_id   category sub_category  \
# 3406   East  FUR-CH-10002965  Furniture       Chairs
#
#                                            product_name  sales_price  \
# 3406  Global Leather Highback Executive Chair with P...      281.372
#
#       quantity  discount   profit
# 3406       2.0       0.3 -12.0588

# %%
df.drop(df[duplicate_rows_mask].index, axis='index', inplace=True)
df.shape
# Out:
# (9993, 20)

# %%
# , 'quantity', 'discount', 'profit'
labels = ['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id', 'product_id', 'product_name', 'category', 'sub_category', 'discount']
duplicate_orderID_rows = df.duplicated(labels)
print(len(df.loc[duplicate_orderID_rows]))
df.loc[duplicate_orderID_rows]
# Out:
# 7
#             order_id order_date ship_date       ship_mode customer_id  \
# 352   CA-2016-129714   01/09/16  03/09/16     First Class    AB-10060
# 431   US-2016-123750   15/04/16  21/04/16  Standard Class    RB-19795
# 1301  CA-2016-137043   23/12/16  25/12/16    Second Class    LC-17140
# 3184  CA-2017-152912   09/11/17  12/11/17    Second Class    BM-11650
# 6500  CA-2015-103135   24/07/15  28/07/15  Standard Class    SS-20515
# 7882  CA-2017-118017   03/12/17  06/12/17    Second Class    LC-16870
# 9169  CA-2016-140571   15/03/16  19/03/16  Standard Class    SJ-20125
#
#         customer_name      segment        country           city  \
# 352   Adam Bellavance  Home Office  United States  New York City
# 431        Ross Baird  Home Office  United States       Gastonia
# 1301     Logan Currie     Consumer  United States    Springfield
# 3184       Brian Moss    Corporate  United States       Columbia
# 6500  Shirley Schmidt  Home Office  United States     Louisville
# 7882    Lena Cacioppo     Consumer  United States       Thornton
# 9169    Sanjit Jacobs  Home Office  United States        Jackson
#
#                state  postal_code region       product_id         category  \
# 352         New York        10009   East  OFF-PA-10001970  Office Supplies
# 431   North Carolina        28052  South  TEC-AC-10004659       Technology
# 1301        Virginia        22153  South  FUR-FU-10003664        Furniture
# 3184        Maryland        21044   East  OFF-ST-10003208  Office Supplies
# 6500        Kentucky        40214  South  OFF-BI-10000069  Office Supplies
# 7882        Colorado        80229   West  TEC-AC-10002006       Technology
# 9169     Mississippi        39212  South  OFF-PA-10001954  Office Supplies
#
#      sub_category                                       product_name  \
# 352         Paper                                         Xerox 1881
# 431   Accessories  Imation�Secure+ Hardware Encrypted USB 2.0�Fla...
# 1301  Furnishings  Electrix Architect's Clamp-On Swing Arm Lamp, ...
# 3184      Storage                 Adjustable Depth Letter/Legal Cart
# 6500      Binders  GBC Prepunched Paper, 19-Hole, for Binding Sys...
# 7882  Accessories                   Memorex Micro Travel Drive 16 GB
# 9169        Paper                                         Xerox 1964
#
#       sales_price  quantity  discount    profit
# 352        49.120       4.0       0.0   23.0864
# 431       291.960       5.0       0.2   54.7425
# 1301      286.380       3.0       0.0   83.0502
# 3184      544.380       3.0       0.0  157.8702
# 6500       90.060       6.0       0.0   41.4276
# 7882      102.336       8.0       0.2   14.0712
# 9169       45.680       2.0       0.0   21.0128

# %%
duplicate_orderID_rows2 = df.duplicated(labels, keep='last')
print(len(df.loc[duplicate_orderID_rows2]))
df.loc[duplicate_orderID_rows2]
# Out:
# 7
#             order_id order_date ship_date       ship_mode customer_id  \
# 350   CA-2016-129714   01/09/16  03/09/16     First Class    AB-10060
# 430   US-2016-123750   15/04/16  21/04/16  Standard Class    RB-19795
# 1300  CA-2016-137043   23/12/16  25/12/16    Second Class    LC-17140
# 3183  CA-2017-152912   09/11/17  12/11/17    Second Class    BM-11650
# 6498  CA-2015-103135   24/07/15  28/07/15  Standard Class    SS-20515
# 7881  CA-2017-118017   03/12/17  06/12/17    Second Class    LC-16870
# 9168  CA-2016-140571   15/03/16  19/03/16  Standard Class    SJ-20125
#
#         customer_name      segment        country           city  \
# 350   Adam Bellavance  Home Office  United States  New York City
# 430        Ross Baird  Home Office  United States       Gastonia
# 1300     Logan Currie     Consumer  United States    Springfield
# 3183       Brian Moss    Corporate  United States       Columbia
# 6498  Shirley Schmidt  Home Office  United States     Louisville
# 7881    Lena Cacioppo     Consumer  United States       Thornton
# 9168    Sanjit Jacobs  Home Office  United States        Jackson
#
#                state  postal_code region       product_id         category  \
# 350         New York        10009   East  OFF-PA-10001970  Office Supplies
# 430   North Carolina        28052  South  TEC-AC-10004659       Technology
# 1300        Virginia        22153  South  FUR-FU-10003664        Furniture
# 3183        Maryland        21044   East  OFF-ST-10003208  Office Supplies
# 6498        Kentucky        40214  South  OFF-BI-10000069  Office Supplies
# 7881        Colorado        80229   West  TEC-AC-10002006       Technology
# 9168     Mississippi        39212  South  OFF-PA-10001954  Office Supplies
#
#      sub_category                                       product_name  \
# 350         Paper                                         Xerox 1881
# 430   Accessories  Imation�Secure+ Hardware Encrypted USB 2.0�Fla...
# 1300  Furnishings  Electrix Architect's Clamp-On Swing Arm Lamp, ...
# 3183      Storage                 Adjustable Depth Letter/Legal Cart
# 6498      Binders  GBC Prepunched Paper, 19-Hole, for Binding Sys...
# 7881  Accessories                   Memorex Micro Travel Drive 16 GB
# 9168        Paper                                         Xerox 1964
#
#       sales_price  quantity  discount    profit
# 350        24.560       2.0       0.0   11.5432
# 430       408.744       7.0       0.2   76.6395
# 1300      572.760       6.0       0.0  166.1004
# 3183     1633.140       9.0       0.0  473.6106
# 6498      135.090       9.0       0.0   62.1414
# 7881       76.752       6.0       0.2   10.5534
# 9168      319.760      14.0       0.0  147.0896

# %% [markdown]
# - there are 7 pairs of records where a pair has all the same columns like 'order_id', 'customer_id', 'product_id', 'ship_date', 'ship_mode', 'postal_code'... but different `sales_price`, `quantity` and `profit`
# - Cannot drop these 7 duplicate rows due to insufficient evidence of them being "real" duplicates

# %% [markdown]
# ### End: Handling Duplicates
# - there are 17 rows where all attributes are duplicated
# - and 20 rows with duplicate `row_id`(s)
# - of the **3 rows with duplicate `row_id`'s**, 1 had a missing `quantity` while other 2 had a sign's difference in the `sales_price`.
# - the -ve sign in the 'sales_price' column appears to be a mistake wherever it may have occured (4 rows)
#   - the above two points prove the point that the **3 rows with duplicate row_id's** are "real" duplicates too.
# - thus, dropped the 20 rows with duplicate row_id
# - changed the -ve sign wherever it occurs in the 'sales_price' attribute
# - dropped the `row_id` column. the index suffices its need
# - there existed one more duplicate row after all that. Dropped that too

# %% [markdown]
# resetting the index because the index is not contiuous due to dropping of duplicate rows

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 3. Date Handling
# - Normalize the Order Date and Ship Date columns to ensure consistent date formats. Ensure that the format of the date is consistent across all rows
# - Extract the year from the Order ID and compare it with the year in the Order Date. Correct any inconsistencies
# - Document the number of rows and distinct Order IDs affected by these operations

# %%
df['order_date'].unique()[0:100]
# Out:
# array(['08/11/16', '12/06/16', '11/10/15', '09/06/14', '15/04/17',
#        '05/12/16', '22/11/15', '11/11/14', '13/05/14', '27/08/14',
#        '09/12/16', '16/07/17', '25/09/15', '16/01/16', '17/09/15',
#        '19/10/17', '08/12/16', '27/12/15', '10/09/17', '17/07/16',
#        '19/09/17', '11/03/16', '20/10/14', '20/06/16', '18/04/15',
#        '11/12/16', '17/06/16', '24/11/17', '30/04/15', '05/12/14',
#        '04/06/16', '18/09/16', '14/09/17', '26/04/15', '09/12/17',
#        '26/11/14', '12/10/14', '03/09/15', '13/11/17', '28/05/17',
#        '26/10/17', '05/04/16', '17/09/16', '31/01/15', '06/11/17',
#        '09/11/17', '17/06/17', '06/09/16', '29/08/16', '01/12/16',
#        '13/11/15', '23/11/17', '15/10/15', '25/12/17', '03/11/16',
#        '25/08/14', '02/03/15', '05/04/15', '26/12/14', '20/09/14',
#        '05/11/17', '06/11/16', '02/02/17', '13/10/16', '05/09/16',
#        '18/09/17', '22/12/17', '07/09/15', '22/10/14', '13/03/16',
#        '31/05/15', '28/05/15', '01/03/14', '20/11/16', '11/05/16',
#        '28/12/15', '16/11/16', '07/11/16', '08/09/14', '05/08/14',
#        '14/09/14', '21/04/17', '21/11/15', '15/12/15', '19/11/14',
#        '28/11/16', '26/08/14', '16/07/16', '12/10/15', '31/10/15',
#        '21/03/14', '06/07/17', '24/06/17', '03/08/14', '17/12/17',
#        '03/06/17', '01/12/17', '09/02/15', '02/01/15', '28/10/16'],
#       dtype=object)

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='%d/%m/%y')
df.dtypes
# Out:
# order_id                 object
# order_date       datetime64[ns]
# ship_date                object
# ship_mode                object
# customer_id              object
# customer_name            object
# segment                  object
# country                  object
# city                     object
# state                    object
# postal_code               int64
# region                   object
# product_id               object
# category                 object
# sub_category             object
# product_name             object
# sales_price             float64
# quantity                float64
# discount                float64
# profit                  float64
# dtype: object

# %% [markdown]
# modified rows = 9993 (all)

# %%
df['ship_date'].unique()[0:100]
# Out:
# array(['11/11/16', '16/06/16', '18/10/15', '2014-6-14', '20/04/17',
#        '10/12/16', '26/11/15', '2014-11-18', '2014-5-15', '2014-9-1',
#        '13/12/16', '18/07/17', '30/09/15', '20/01/16', '21/09/15',
#        '23/10/17', '31/12/15', '15/09/17', '22/07/16', '23/09/17',
#        '13/03/16', '2014-10-25', '25/06/16', '22/04/15', '17/12/16',
#        '18/06/16', '30/11/15', '05/05/15', '2014-12-10', '06/06/16',
#        '23/09/16', '17/09/17', '02/05/15', '11/12/17', '2014-12-1',
#        '15/06/16', '2014-10-16', '08/09/15', '16/11/17', '30/05/17',
#        '02/11/17', '10/04/16', '22/09/16', '05/02/15', '12/11/17',
#        '11/11/17', '20/06/17', '11/09/16', '02/09/16', '04/12/16',
#        '17/11/15', '28/11/17', '20/10/15', '30/12/17', '10/11/16',
#        '2014-8-27', '06/03/15', '10/04/15', '2014-12-28', '2014-9-25',
#        '05/02/17', '19/10/16', '07/09/16', '27/12/17', '12/09/15',
#        '2014-10-28', '09/12/16', '16/03/16', '02/06/15', '03/06/15',
#        '2014-3-6', '24/11/16', '12/05/16', '20/11/16', '2014-9-12',
#        '2014-8-9', '2014-9-19', '25/04/17', '23/11/15', '19/12/15',
#        '2014-12-9', '2014-11-24', '02/12/16', '2014-8-30', '14/10/15',
#        '06/11/15', '2014-3-25', '13/11/17', '13/07/17', '29/06/17',
#        '2014-8-5', '21/12/17', '07/06/17', '14/12/17', '07/12/17',
#        '13/02/15', '09/01/15', '01/11/16', '27/12/15', '16/08/15'],
#       dtype=object)

# %%
# handling ship dates of type - dd/mm/yy
dt_type1_mask = df['ship_date'].str.contains(r'\d{2}[/]\d{2}[/]\d{2}', regex=True, na=False)
df.loc[ dt_type1_mask, 'ship_date' ]
# Out:
# 0       11/11/16
# 1       11/11/16
# 2       16/06/16
# 3       18/10/15
# 4       18/10/15
#           ...
# 9986    21/11/17
# 9988    03/03/17
# 9989    03/03/17
# 9990    03/03/17
# 9991    09/05/17
# Name: ship_date, Length: 8054, dtype: object

# %%
df.loc[dt_type1_mask, 'ship_date'] = pd.to_datetime(df.loc[dt_type1_mask, 'ship_date'], format='%d/%m/%y')
df.loc[ dt_type1_mask, 'ship_date' ]
# Out:
# 0       2016-11-11 00:00:00
# 1       2016-11-11 00:00:00
# 2       2016-06-16 00:00:00
# 3       2015-10-18 00:00:00
# 4       2015-10-18 00:00:00
#                ...
# 9986    2017-11-21 00:00:00
# 9988    2017-03-03 00:00:00
# 9989    2017-03-03 00:00:00
# 9990    2017-03-03 00:00:00
# 9991    2017-05-09 00:00:00
# Name: ship_date, Length: 8054, dtype: object

# %%
# handling dates of type - yyyy-mm-dd
dt_type2_mask = df['ship_date'].str.contains(r'\d{4}[-]\d{1,2}[-]\d{1,2}', regex=True, na=False)
df.loc[ dt_type2_mask, 'ship_date' ]
# Out:
# 5        2014-6-14
# 6        2014-6-14
# 7        2014-6-14
# 8        2014-6-14
# 9        2014-6-14
#            ...
# 9954    2014-11-17
# 9955    2014-11-17
# 9956    2014-11-17
# 9987     2014-1-23
# 9992      2014-9-1
# Name: ship_date, Length: 1939, dtype: object

# %%
df.loc[dt_type2_mask, 'ship_date'] = pd.to_datetime(df.loc[dt_type2_mask, 'ship_date'], format='%Y-%m-%d')
df.loc[ dt_type2_mask, 'ship_date' ]
# Out:
# 5       2014-06-14 00:00:00
# 6       2014-06-14 00:00:00
# 7       2014-06-14 00:00:00
# 8       2014-06-14 00:00:00
# 9       2014-06-14 00:00:00
#                ...
# 9954    2014-11-17 00:00:00
# 9955    2014-11-17 00:00:00
# 9956    2014-11-17 00:00:00
# 9987    2014-01-23 00:00:00
# 9992    2014-09-01 00:00:00
# Name: ship_date, Length: 1939, dtype: object

# %% [markdown]
# modified rows in the ship_date column = (8054 + 1939) = 9993

# %%
df = df.astype({'ship_date':'datetime64[ns]'})
df.dtypes
# Out:
# order_id                 object
# order_date       datetime64[ns]
# ship_date        datetime64[ns]
# ship_mode                object
# customer_id              object
# customer_name            object
# segment                  object
# country                  object
# city                     object
# state                    object
# postal_code               int64
# region                   object
# product_id               object
# category                 object
# sub_category             object
# product_name             object
# sales_price             float64
# quantity                float64
# discount                float64
# profit                  float64
# dtype: object

# %% [markdown]
# no data lost in normalizing dates!!

# %% [markdown]
# ### check whether or not the years in `order_date` and `order_id` match

# %%
# order_id -> xx-YYYY-xxxxxx
order_id_yrs = df['order_id'].str.extract(r'-(\d{2,4})-', expand=False).astype('int')
order_date_yrs = df['order_date'].dt.year
inconsistent_order_dates_mask = (order_id_yrs != order_date_yrs)

inconsistent_order_dates = df[inconsistent_order_dates_mask]
inconsistent_order_dates
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 61    CA-2015-135545 2017-11-24 2015-11-30  Standard Class    KM-16720
# 62    CA-2015-135545 2017-11-24 2015-11-30  Standard Class    KM-16720
# 63    CA-2015-135545 2017-11-24 2015-11-30  Standard Class    KM-16720
# 64    CA-2015-135545 2017-11-24 2015-11-30  Standard Class    KM-16720
# 942   CA-2015-120880 2013-05-29 2015-06-03  Standard Class    JL-15850
# 943   CA-2015-120880 2013-05-29 2015-06-03  Standard Class    JL-15850
# 944   CA-2015-120880 2013-05-29 2015-06-03  Standard Class    JL-15850
# 1151  CA-2017-160395 2016-12-31 2017-01-06  Standard Class    KL-16555
# 1152  CA-2017-160395 2016-12-31 2017-01-06  Standard Class    KL-16555
# 2751  CA-2015-155306 1999-04-17 2015-04-21  Standard Class    GA-14515
# 2752  CA-2015-155306 1999-04-17 2015-04-21  Standard Class    GA-14515
# 2753  CA-2015-155306 1999-04-17 2015-04-21  Standard Class    GA-14515
# 2754  CA-2015-155306 1999-04-17 2015-04-21  Standard Class    GA-14515
# 2755  CA-2015-155306 1999-04-17 2015-04-21  Standard Class    GA-14515
# 2820  CA-2017-100202 2016-12-31 2017-01-05  Standard Class    BD-11620
# 3535  CA-2014-158771 2015-05-09 2014-05-09        Same Day    SB-20290
# 3536  CA-2014-158771 2015-05-09 2014-05-09        Same Day    SB-20290
# 3537  CA-2014-158771 2015-05-09 2014-05-09        Same Day    SB-20290
# 3538  CA-2014-158771 2015-05-09 2014-05-09        Same Day    SB-20290
# 4446  CA-2015-121965 2017-06-19 2015-06-23  Standard Class    LH-17155
# 4447  CA-2015-121965 2017-06-19 2015-06-23  Standard Class    LH-17155
# 4448  CA-2015-121965 2017-06-19 2015-06-23  Standard Class    LH-17155
# 4610  US-2017-165953 2016-12-31 2017-01-06  Standard Class    EP-13915
# 4611  US-2017-165953 2016-12-31 2017-01-06  Standard Class    EP-13915
# 5287  CA-2014-146283 2016-09-08 2014-09-15  Standard Class    KT-16465
# 5288  CA-2014-146283 2016-09-08 2014-09-15  Standard Class    KT-16465
# 5289  CA-2014-146283 2016-09-08 2014-09-15  Standard Class    KT-16465
# 5370  CA-2015-118738 2014-10-24 2015-10-30  Standard Class    AG-10495
# 62    Acco PRESSTEX Data Binder with Storage Hooks, ...       25.824
# 63                                           Xerox 1943      146.730
# 64                          Luxo Economy Swing Arm Lamp       79.760
# 942                                          Xerox 1894       32.400
# 943                    Standard Rollaway File with Lock      540.570
# 944         Avery Trapezoid Extra Heavy Duty 4" Binders      167.760
# 1151                   Crayola Anti Dust Chalk, 12/Pack        3.640
# 1152                        Lock-Up Easel 'Spel-Binder'      159.768
# 2751                           Prang Drawing Pencil Set        5.560
# 2752    Plantronics S12 Corded Telephone Headset System      323.370
# 2753  Plantronics Calisto P620-M USB Wireless Speake...      783.960
# 2754                Hoover Upright Vacuum With Dirt Cup     1447.650
# 2755                                         Xerox 1903       11.960
# 2820                                   Adtran 1202752G1      302.376
# 3535                         Fellowes Super Stor/Drawer       83.250
# 3536                                          Avery 518        9.450
# 3537                                          Avery 506       20.650
# 3538  Weyerhaeuser First Choice Laser/Copy Paper (20...       45.360
# 4446                   Eldon 200 Class Desk Accessories       12.560
# 4447                                          Xerox 231        6.480
# 4448                        Cameo Buff Policy Envelopes      186.690
# 4610                                         Newell 345       47.616
# 4611                             Things To Do Today Pad       23.480
# 5287  Geographics Note Cards, Blank, White, 8 1/2" x...       17.904
# 5288                           SAFCO Arco Folding Chair      966.700
# 5289  Snap-A-Way Black Print Carbonless Ruled Speed ...      182.112
# 5370                                         Xerox 1999       15.552
# 5371                               KI Conference Tables      347.361
# 5372                                            Xerox 2       10.368
# 5736  GBC Pre-Punched Binding Paper, Plastic, White,...       38.376
# 6339                        Tennsco Industrial Shelving      156.512
# 6385                                         Xerox 1972       10.560
# 6386      Space Solutions HD Industrial Steel Shelving.      229.940
# 8584                 Logitech�P710e Mobile Speakerphone     1287.450
# 8585  Fellowes 8 Outlet Superior Workstation Surge P...      168.100
# 8593                            Storex Dura Pro Binders       11.880
# 8594                                  Easy-staple paper       35.440
# 9940        Carina Mini System Audio Rack, Model AR050B      998.820
# 9941                           Acme Box Cutter Scissors       51.150
#
#       quantity  discount    profit
# 61         2.0       0.0    6.1512
# 62         6.0       0.2    9.3612
# 63         3.0       0.0   68.9631
# 64         4.0       0.0   22.3328
# 942        5.0       0.0   15.5520
# 943        3.0       0.0  140.5482
# 944        5.0       0.2   62.9100
# 1151       2.0       0.0    1.6380
# 1152       7.0       0.2   53.9217
# 2751       2.0       0.0    2.2240
# 2752       3.0       0.0  129.3480
# 2753       5.0       0.2   68.5965
# 2754       5.0       0.0  419.8185
# 2755       2.0       0.0    5.8604
# 2820       3.0       0.2   22.6782
# 3535       3.0       0.0   14.9850
# 3536       3.0       0.0    4.5360
# 3537       5.0       0.0    9.4990
# 3538       7.0       0.0   21.7728
# 4446       2.0       0.0    4.0192
# 4447       1.0       0.0    3.1104
# 4448       3.0       0.0   87.7443
# 4610       3.0       0.2    3.5712
# 4611       5.0       0.2    8.2180
# 5287       2.0       0.2    6.2664
# 5288       5.0       0.3  -13.8100
# 5289       6.0       0.2   61.4628
# 5370       3.0       0.2    5.4432
# 5371       7.0       0.3  -69.4722
# 5372       2.0       0.2    3.6288
# 5736       3.0       0.2   13.4316
# 6339       4.0       0.2  -35.2152
# 6385       2.0       0.0    4.7520
# 6386       2.0       0.0    6.8982
# 8584       5.0       0.0  244.6155
# 8585       5.0       0.0   43.7060
# 8593       2.0       0.0    5.3460
# 8594       1.0       0.0   16.6568
# 9940       9.0       0.0   29.9646
# 9941       5.0       0.0   13.2990

# %% [markdown]
# #### replacing the years in `order_date` with years in `order_id`

# %%
inconsistent_order_dates.shape
# Out:
# (40, 20)

# %%
df['year_diff'] = order_id_yrs - order_date_yrs
df['order_date'] = df.apply(lambda x: x['order_date'] + pd.DateOffset(years=x['year_diff']), axis='columns')

# %%
df.loc[inconsistent_order_dates_mask, ['order_id', 'order_date']]
# Out:
#             order_id order_date
# 61    CA-2015-135545 2015-11-24
# 62    CA-2015-135545 2015-11-24
# 63    CA-2015-135545 2015-11-24
# 64    CA-2015-135545 2015-11-24
# 942   CA-2015-120880 2015-05-29
# 943   CA-2015-120880 2015-05-29
# 944   CA-2015-120880 2015-05-29
# 1151  CA-2017-160395 2017-12-31
# 1152  CA-2017-160395 2017-12-31
# 2751  CA-2015-155306 2015-04-17
# 2752  CA-2015-155306 2015-04-17
# 2753  CA-2015-155306 2015-04-17
# 2754  CA-2015-155306 2015-04-17
# 2755  CA-2015-155306 2015-04-17
# 2820  CA-2017-100202 2017-12-31
# 3535  CA-2014-158771 2014-05-09
# 3536  CA-2014-158771 2014-05-09
# 3537  CA-2014-158771 2014-05-09
# 3538  CA-2014-158771 2014-05-09
# 4446  CA-2015-121965 2015-06-19
# 4447  CA-2015-121965 2015-06-19
# 4448  CA-2015-121965 2015-06-19
# 4610  US-2017-165953 2017-12-31
# 4611  US-2017-165953 2017-12-31
# 5287  CA-2014-146283 2014-09-08
# 5288  CA-2014-146283 2014-09-08
# 5289  CA-2014-146283 2014-09-08
# 5370  CA-2015-118738 2015-10-24
# 5371  CA-2015-118738 2015-10-24
# 5372  CA-2015-118738 2015-10-24
# 5736  CA-2017-156139 2017-12-31
# 6339  US-2017-105830 2017-12-31
# 6385  CA-2014-134103 2014-01-30
# 6386  CA-2014-134103 2014-01-30
# 8584  CA-2017-162015 2017-07-11
# 8585  CA-2017-162015 2017-07-11
# 8593  CA-2014-111934 2014-05-05
# 8594  CA-2014-111934 2014-05-05
# 9940  CA-2014-143371 2014-12-28
# 9941  CA-2014-143371 2014-12-28

# %%
df.dtypes
# Out:
# order_id                 object
# order_date       datetime64[ns]
# ship_date        datetime64[ns]
# ship_mode                object
# customer_id              object
# customer_name            object
# segment                  object
# country                  object
# city                     object
# state                    object
# postal_code               int64
# region                   object
# product_id               object
# category                 object
# sub_category             object
# product_name             object
# sales_price             float64
# quantity                float64
# discount                float64
# profit                  float64
# year_diff                 int64
# dtype: object

# %% [markdown]
# ## 4. Imputation of Missing Values
# - Impute missing values in the Ship Mode column using the calculated Days to Ship column
# - Calculate Days to Ship as the difference between Ship Date and Order Date. If Days to Ship is 0, set Ship Mode to "Same Day"; if it is 7, set Ship Mode to "Standard Class"
# - Impute missing values in the Quantity column using a method of your choice. Print the rationale for selecting the imputation method
# - Document the number of rows and distinct Order IDs affected by these operations

# %%
df.isna().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode        98
# customer_id       0
# customer_name     0
# segment           0
# country           0
# city              0
# state             0
# postal_code       0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales_price       0
# quantity         17
# discount          0
# profit            0
# year_diff         0
# dtype: int64

# %%
df['days_to_ship'] = (df['ship_date'] - df['order_date']).dt.days
df['days_to_ship'].unique()
# Out:
# array([   3,    4,    7,    5,    2,    6,    1,    0, -359, -360, -363])

# %%
print(len(df[df['days_to_ship']<0]))
print(len(df[inconsistent_order_dates_mask]))
df[ df['days_to_ship']<0 & inconsistent_order_dates_mask]
# Out:
# 7
# 40
#             order_id order_date  ship_date       ship_mode customer_id  \
# 1151  CA-2017-160395 2017-12-31 2017-01-06  Standard Class    KL-16555
# 1152  CA-2017-160395 2017-12-31 2017-01-06  Standard Class    KL-16555
# 2820  CA-2017-100202 2017-12-31 2017-01-05  Standard Class    BD-11620
# 4610  US-2017-165953 2017-12-31 2017-01-06  Standard Class    EP-13915
# 4611  US-2017-165953 2017-12-31 2017-01-06  Standard Class    EP-13915
# 5736  CA-2017-156139 2017-12-31 2017-01-06  Standard Class    BP-11155
# 6339  US-2017-105830 2017-12-31 2017-01-02     First Class    DB-13660
#
#         customer_name    segment        country           city       state  \
# 1151    Kelly Lampkin  Corporate  United States           Reno      Nevada
# 1152    Kelly Lampkin  Corporate  United States           Reno      Nevada
# 2820  Brian DeCherney   Consumer  United States        Anaheim  California
# 4610       Emily Phan   Consumer  United States   Jacksonville     Florida
# 4611       Emily Phan   Consumer  United States   Jacksonville     Florida
# 5736        Becky Pak   Consumer  United States  San Francisco  California
# 6339     Duane Benoit   Consumer  United States      Lancaster        Ohio
#
#       postal_code region       product_id         category sub_category  \
# 1151        89502   West  OFF-AR-10003759  Office Supplies          Art
# 1152        89502   West  OFF-BI-10003984  Office Supplies      Binders
# 2820        92804   West  TEC-PH-10002563       Technology       Phones
# 4610        32216  South  OFF-AR-10000588  Office Supplies          Art
# 4611        32216  South  OFF-PA-10002250  Office Supplies        Paper
# 5736        94109   West  OFF-BI-10004233  Office Supplies      Binders
# 6339        43130   East  OFF-ST-10002554  Office Supplies      Storage
#
#                                            product_name  sales_price  \
# 1151                   Crayola Anti Dust Chalk, 12/Pack        3.640
# 1152                        Lock-Up Easel 'Spel-Binder'      159.768
# 2820                                   Adtran 1202752G1      302.376
# 4610                                         Newell 345       47.616
# 4611                             Things To Do Today Pad       23.480
# 5736  GBC Pre-Punched Binding Paper, Plastic, White,...       38.376
# 6339                        Tennsco Industrial Shelving      156.512
#
#       quantity  discount   profit  year_diff  days_to_ship
# 1151       2.0       0.0   1.6380          1          -359
# 1152       7.0       0.2  53.9217          1          -359
# 2820       3.0       0.2  22.6782          1          -360
# 4610       3.0       0.2   3.5712          1          -359
# 4611       5.0       0.2   8.2180          1          -359
# 5736       3.0       0.2  13.4316          1          -359
# 6339       4.0       0.2 -35.2152          1          -363

# %% [markdown]
# - changing the `ship_date` of these 7 rows to Jan of 2018 because it seems that these the ship date has accidentally been filled incorrectly

# %%
df.loc[df['days_to_ship']<0 & inconsistent_order_dates_mask, 'ship_date'] = df['ship_date'] + pd.DateOffset(years=1)
df.loc[df['days_to_ship']<0 & inconsistent_order_dates_mask, 'ship_date']
# Out:
# 1151   2018-01-06
# 1152   2018-01-06
# 2820   2018-01-05
# 4610   2018-01-06
# 4611   2018-01-06
# 5736   2018-01-06
# 6339   2018-01-02
# Name: ship_date, dtype: datetime64[ns]

# %% [markdown]
# - do there exist `days_to_ship` values other than 0 or 7?

# %%
df['days_to_ship'] = (df['ship_date'] - df['order_date']).dt.days
df['days_to_ship'].unique()
# Out:
# array([3, 4, 7, 5, 2, 6, 1, 0])

# %% [markdown]
# - filling the ship mode as specified

# %%
df.loc[df['ship_mode'].isna() & (df['days_to_ship'] == 0), 'ship_mode'] = 'Same Day'
df.loc[df['ship_mode'].isna() & (df['days_to_ship'] == 7), 'ship_mode'] = 'Standard Class'

df.isna().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_id       0
# customer_name     0
# segment           0
# country           0
# city              0
# state             0
# postal_code       0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales_price       0
# quantity         17
# discount          0
# profit            0
# year_diff         0
# days_to_ship      0
# dtype: int64

# %%
df.drop(columns=['year_diff'], inplace=True)

# %%
df.loc[df['quantity'].isna()]
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 13    CA-2016-161389 2016-12-05 2016-12-10  Standard Class    IM-15070
# 15    US-2015-118983 2015-11-22 2015-11-26  Standard Class    HP-14815
# 23    CA-2015-106320 2015-09-25 2015-09-30  Standard Class    EB-13870
# 25    CA-2016-121755 2016-01-16 2016-01-20    Second Class    EH-13945
# 28    US-2015-150630 2015-09-17 2015-09-21  Standard Class    TB-21520
# 9056  CA-2015-149097 2015-10-20 2015-10-24  Standard Class    SV-20785
# 9062  US-2014-151015 2014-10-14 2014-10-20  Standard Class    BD-11500
# 9066  CA-2016-106278 2016-09-02 2016-09-05    Second Class    BM-11140
# 9067  CA-2016-106278 2016-09-02 2016-09-05    Second Class    BM-11140
# 9068  CA-2017-147550 2017-12-04 2017-12-05     First Class    KE-16420
# 9073  US-2015-136259 2015-11-05 2015-11-08     First Class    CB-12415
# 9485  US-2017-125213 2017-12-11 2017-12-13     First Class    NB-18655
# 9489  CA-2017-111738 2017-01-03 2017-01-07  Standard Class    CM-12385
# 9496  CA-2017-118213 2017-11-05 2017-11-07     First Class    AB-10060
# 9498  CA-2016-149237 2016-05-26 2016-05-30  Standard Class    CM-12235
# 9499  US-2015-158589 2015-11-20 2015-11-24  Standard Class    KW-16570
# 9506  CA-2014-149104 2014-04-05 2014-04-07    Second Class    RD-19900
#
#              customer_name      segment        country              city  \
# 13            Irene Maddox     Consumer  United States           Seattle
# 15           Harold Pawlan  Home Office  United States        Fort Worth
# 23             Emily Burns     Consumer  United States              Orem
# 25           Eric Hoffmann     Consumer  United States       Los Angeles
# 28         Tracy Blumstein     Consumer  United States      Philadelphia
# 9056      Stewart Visinsky     Consumer  United States       Los Angeles
# 9062       Bradley Drucker     Consumer  United States           Chicago
# 9066          Becky Martin     Consumer  United States        Des Moines
# 9067          Becky Martin     Consumer  United States        Des Moines
# 9068       Katrina Edelman    Corporate  United States      Philadelphia
# 9073      Christy Brittain     Consumer  United States          Lakewood
# 9485             Nona Balk    Corporate  United States          Paterson
# 9489  Christopher Martinez     Consumer  United States     San Francisco
# 9496       Adam Bellavance  Home Office  United States         Greenwood
# 9498          Chris McAfee     Consumer  United States         Milwaukee
# 9499        Kelly Williams     Consumer  United States     San Francisco
# 9506           Ruben Dartt     Consumer  United States  Dearborn Heights
#
#              state  postal_code   region       product_id         category  \
# 13      Washington        98103     West  OFF-BI-10003656  Office Supplies
# 15           Texas        76106  Central  OFF-BI-10000756  Office Supplies
# 23            Utah        84057     West  FUR-TA-10000577        Furniture
# 25      California        90049     West  TEC-AC-10003027       Technology
# 28    Pennsylvania        19140     East  FUR-FU-10004848        Furniture
# 9056    California        90045     West  FUR-TA-10001086        Furniture
# 9062      Illinois        60653  Central  OFF-BI-10000343  Office Supplies
# 9066    Washington        98198     West  FUR-CH-10003061        Furniture
# 9067    Washington        98198     West  OFF-EN-10003567  Office Supplies
# 9068  Pennsylvania        19134     East  FUR-FU-10001918        Furniture
# 9073          Ohio        44107     East  OFF-BI-10000773  Office Supplies
# 9485    New Jersey         7501     East  OFF-FA-10001561  Office Supplies
# 9489    California        94110     West  OFF-AR-10000817  Office Supplies
# 9496       Indiana        46142  Central  OFF-PA-10000565  Office Supplies
# 9498     Wisconsin        53209  Central  FUR-FU-10002088        Furniture
# 9499    California        94109     West  FUR-FU-10001546        Furniture
# 9506      Michigan        48127  Central  OFF-AR-10004685  Office Supplies
#
#      sub_category                                       product_name  \
# 13        Binders        Fellowes PB200 Plastic Comb Binding Machine
# 15        Binders   Storex DuraTech Recycled Plastic Frosted Binders
# 23         Tables      Bretford CR4500 Series Slim Rectangular Table
# 25    Accessories   Imation�8GB Mini TravelDrive USB 2.0�Flash Drive
# 28    Furnishings  Howard Miller 13-3/4" Diameter Brushed Chrome ...
# 9056       Tables  SAFCO PlanMaster Boards, 60w x 37-1/2d, White ...
# 9062      Binders  Pressboard Covers with Storage Hooks, 9 1/2" x...
# 9066       Chairs                   Global Leather Task Chair, Black
# 9067    Envelopes  Inter-Office Recycled Envelopes, Brown Kraft, ...
# 9068  Furnishings  C-Line Cubicle Keepers Polyproplyene Holder Wi...
# 9073      Binders                Insertable Tab Post Binder Dividers
# 9485    Fasteners                                Stockwell Push Pins
# 9489          Art             Manco Dry-Lighter Erasable Highlighter
# 9496        Paper                                  Easy-staple paper
# 9498  Furnishings                    Nu-Dell Float Frame 11 x 14 1/2
# 9499  Furnishings                               Dana Swing-Arm Lamps
# 9506          Art  Binney & Smith Crayola Metallic Colored Pencil...
#
#       sales_price  quantity  discount    profit  days_to_ship
# 13        407.976       NaN       0.2  132.5922             5
# 15          2.544       NaN       0.8   -3.8160             4
# 23       1044.630       NaN       0.0  240.2649             5
# 25         90.570       NaN       0.0   11.7741             4
# 28        124.200       NaN       0.2   15.5250             4
# 9056      364.776       NaN       0.2   27.3582             4
# 9062        2.946       NaN       0.8   -4.8609             6
# 9066      215.976       NaN       0.2   -2.6997             3
# 9067       65.940       NaN       0.0   30.9918             3
# 9068       11.352       NaN       0.2    2.6961             1
# 9073        7.218       NaN       0.7   -5.5338             3
# 9485        6.540       NaN       0.0    2.1582             2
# 9489        9.120       NaN       0.0    3.1008             4
# 9496      167.940       NaN       0.0   82.2906             2
# 9498       26.940       NaN       0.0   11.3148             4
# 9499       32.040       NaN       0.0    8.0100             4
# 9506       13.890       NaN       0.0    4.5837             2

# %% [markdown]
# using <mark>median of product sub-category</mark> for imputation
# The reasons for such imputation are:
# - grouping by sub-category will reflect the typical quantity for each product type
#   grouping by category is misleading as different things are bought in different quantities.
#   For example, a office will buy <ins>lesser amount of art</ins> and a <ins>higher amount of tables and chairs</ins>
# - median is less sensitive to extreme values (outliers) compared to the mean.

# %%
df['quantity'] = df.groupby('sub_category')['quantity'].transform(lambda x: x.fillna(x.median()))
df.isna().sum()
# Out:
# order_id         0
# order_date       0
# ship_date        0
# ship_mode        0
# customer_id      0
# customer_name    0
# segment          0
# country          0
# city             0
# state            0
# postal_code      0
# region           0
# product_id       0
# category         0
# sub_category     0
# product_name     0
# sales_price      0
# quantity         0
# discount         0
# profit           0
# days_to_ship     0
# dtype: int64

# %% [markdown]
# ## 5. Data Masking and String Handling:
# - Drop the Customer Name column to protect Personal Identifiable Information (PII).
# - Create a new column called Customer Name Masked, containing only the initials of the customer name.
# > Note: It's important to protect PII in datasets to maintain customer privacy and comply with data protection regulations. Masking or dropping sensitive data like customer names is a crucial step in this process.
# - Convert the Postal Code column from numeric to text format, ensuring all codes are 5 characters long. Add a leading '0' where necessary.

# %%
# df['customer_name_masked'] = df['customer_name'].str.replace(r'[a-z\W]', ' ', regex=True)
df['customer_name_masked'] = df['customer_name'].str.replace(r'^(\w).*[\s-](\w).*', '\\1 \\2', regex=True)
df['customer_name_masked'].unique()
# Out:
# array(['C G', 'D H', 'S O', 'B H', 'A A', 'I M', 'H P', 'P K', 'A G',
#        'Z D', 'K B', 'S F', 'E B', 'E H', 'T B', 'M A', 'G H', 'S N',
#        'L C', 'R A', 'E S', 'O N', 'P O', 'L H', 'D P', 'J M', 'K M',
#        'P S', 'B S', 'K D', 'H M', 'J E', 'S C', 'D N', 'J C', 'C S',
#        'P G', 'G M', 'J S', 'R B', 'P N', 'E R', 'G Z', 'P A', 'C V',
#        'C L', 'R C', 'D K', 'G G', 'A D', 'P F', 'T S', 'L S', 'D W',
#        'J D', 'S H', 'S G', 'H A', 'M G', 'T W', 'S P', 'N K', 'D B',
#        'N P', 'T T', 'E M', 'R D', 'M J', 'B M', 'J B', 'S J', 'J K',
#        'R M', 'S K', 'F M', 'A M', 'M P', 'M Z', 'C B', 'V M', 'F H',
#        'M B', 'H K', 'L E', 'J H', 'M S', 'V W', 'D S', 'V D', 'E A',
#        'K L', 'K C', 'D L', 'D R', 'C C', 'D l', 'S B', 'A H', 'C A',
#        'K H', 'B B', 'J O', 'N Z', 'A S', 'C R', 'B P', 'N M', 'F A',
#        'G K', 'D J', 'J L', 'A C', 'T D', 'A B', 'V B', 'K W', 'M K',
#        'G T', 'M M', 'A R', 'L A', 'D O', 'N G', 'M V', 'J G', 'V P',
#        'S S', 'L F', 'R F', 'C J', 'P B', 'N F', 'S D', 'T N', 'M H',
#        'J P', 'X P', 'M T', 'S R', 'C W', 'A J', 'R O', 'M D', 'M Y',
#        'C M', 'B N', 'M C', 'B D', 'P H', 'R L', 'E P', 'L M', 'O T',
#        'L P', 'J F', 'F P', 'T G', 'D V', 'Z C', 'L R', 'T P', 'C K',
#        'N B', 'G D', 'M O', 'A T', 'M E', 'T H', 'R P', 'C D', 'A P',
#        'R S', 'S V', 'M R', 'E G', 'Y C', 'D C', 'C P', 'B F', 'B V',
#        'L T', 'R H', 'H W', 'P J', 'B W', 'T R', 'A F', 'G A', 'B K',
#        'G P', 'S M', 'P M', 'L L', 'E L', 'P C', 'H L', 'G B', 'J R',
#        'B E', 'S A', 'R W', 'S E', 'J J', 'R K', 'S W', 'J A', 'L W',
#        'T Z', 'S L', 'M W', 'V G', 'H R', 'D E', 'N S', 'D G', 'F O',
#        'B T', 'C Y', 'N C', 'K T', 'B G', 'E J', 'Q J', 'T C', 'H G',
#        'F G', 'L D', 'M N', 'N D', 'L B', 'S Z', 'P P', 'Y S', 'S T',
#        'P W', 'N H', 'K N', 'J W', 'A I', 'P L', 'I G', 'B O', 'A W',
#        'M L', 'N W', 'H H', 'H F', 'H Z', 'E D', 'D A', 'C H', 'G W',
#        'C T', 'K A', 'W B', 'K F', 'I L', 'B C', 'T M', 'A Z', 'R R',
#        'L O', 'E N', 'T A', 'N L', 'D F', 'D p', 'D M', 'V F', 'A Y',
#        'R E', 'E C', 'P T', 'P R', 'H J', 'S U', 'F C', 'M F', 'K E',
#        'V T', 'D D', 'E K', 'G R', 'V S', 'N R', 'K S', 'A O', 'F W',
#        'H E', 'H D'], dtype=object)

# %%
# storing the dataframe with 'customer_names' column before dropping the column
data = df.copy(deep=True)

# drop the pii column 'customer_name'
df.drop(columns=['customer_name'], inplace=True)
df.head()
# Out:
#          order_id order_date  ship_date       ship_mode customer_id  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      segment        country             city       state  postal_code region  \
# 0   Consumer  United States        Henderson    Kentucky        42420  South
# 1   Consumer  United States        Henderson    Kentucky        42420  South
# 2  Corporate  United States      Los Angeles  California        90036   West
# 3   Consumer  United States  Fort Lauderdale     Florida        33311  South
# 4   Consumer  United States  Fort Lauderdale     Florida        33311  South
#
#         product_id         category sub_category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name  sales_price  quantity  \
# 0                  Bush Somerset Collection Bookcase     261.9600       2.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400       3.0
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200       2.0
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775       5.0
# 4                     Eldon Fold 'N Roll Cart System      22.3680       2.0
#
#    discount    profit  days_to_ship customer_name_masked
# 0      0.00   41.9136             3                  C G
# 1      0.00  219.5820             3                  C G
# 2      0.00    6.8714             4                  D H
# 3      0.45 -383.0310             7                  S O
# 4      0.20    2.5164             7                  S O

# %%
# postal codes of string type will prevent arithmetic operations on them.  
df['postal_code'] = df['postal_code'].astype('string')
df.dtypes
# Out:
# order_id                        object
# order_date              datetime64[ns]
# ship_date               datetime64[ns]
# ship_mode                       object
# customer_id                     object
# segment                         object
# country                         object
# city                            object
# state                           object
# postal_code             string[python]
# region                          object
# product_id                      object
# category                        object
# sub_category                    object
# product_name                    object
# sales_price                    float64
# quantity                       float64
# discount                       float64
# profit                         float64
# days_to_ship                     int64
# customer_name_masked            object
# dtype: object

# %%
print(f'# of rows with postal codes of length != 5: {len(df.loc[df['postal_code'].str.len() != 5])}')
# Out:
# # of rows with postal codes of length != 5: 449

# %%
df['postal_code'] = df['postal_code'].str.rjust(5, fillchar='0')
df.loc[(df['postal_code'].str.len() != 5), 'postal_code']
# Out:
# Series([], Name: postal_code, dtype: string)

# %% [markdown]
# - an empty series means that all the postal code are 5 lettered
# - No of affected rows = xx

# %% [markdown]
# ## 6. Data Type Conversion
# - Convert the Quantity and Sales Price columns from strings to their appropriate numeric types (int and float, respectively)

# %%
df['quantity'] = df['quantity'].astype('int')

# %%
df.dtypes
# Out:
# order_id                        object
# order_date              datetime64[ns]
# ship_date               datetime64[ns]
# ship_mode                       object
# customer_id                     object
# segment                         object
# country                         object
# city                            object
# state                           object
# postal_code             string[python]
# region                          object
# product_id                      object
# category                        object
# sub_category                    object
# product_name                    object
# sales_price                    float64
# quantity                         int64
# discount                       float64
# profit                         float64
# days_to_ship                     int64
# customer_name_masked            object
# dtype: object

# %% [markdown]
# ## 7. Handling Inconsistent Categorical Data
# - Clean the State column by replacing abbreviations with full state names (e.g., "CA" should be changed to "California"). You may need to research state abbreviations online to ensure all entries are corrected consistently

# %%
df['state'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee', 'TX',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'CA ', 'New Hampshire',
#        'Maryland', 'District of Columbia', 'WA\\', 'NJ', 'Kansas',
#        'Vermont', 'Maine', 'South Dakota', 'Idaho', 'North Dakota',
#        'Wyoming', 'West Virginia', 'NY'], dtype=object)

# %%
us_states = {
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming'
}

# %%
abbs_mask = df['state'].str.contains(r'^[A-Z]{2}.*$', regex=True)
print(f'no of rows with state abbrevations = {len(df[abbs_mask])}')
df.loc[abbs_mask, 'state']
# Out:
# no of rows with state abbrevations = 266
# 74      TX
# 75      TX
# 76      TX
# 77      TX
# 87      TX
#         ..
# 9938    NY
# 9954    NY
# 9955    NY
# 9956    NY
# 9982    NY
# Name: state, Length: 266, dtype: object

# %%
# all us states have two (uppercase) lettered abbrevations.
import re
for abb, name in us_states.items():
    pat = r"^" + re.escape(abb) + r".*$"
    repl = name
    df.loc[abbs_mask, 'state'] = df.loc[abbs_mask, 'state'].str.replace(pat, repl, regex=True)

df['state'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
print(f'no of rows with state abbrevations before changes = {len(df[abbs_mask])}')
abbs_mask = df['state'].str.contains(r'^[A-Z]{2}.*$', regex=True)
print(f'no of rows with state abbrevations after changes = {len(df[abbs_mask])}')
# Out:
# no of rows with state abbrevations before changes = 0
# no of rows with state abbrevations after changes = 0

# %% [markdown]
# No. of rows affected = 266

# %% [markdown]
# ## 8. Feature Engineering
# - Create new columns
#      - Original Price: The price before any discount is applied
#      - Total Sales: The total revenue is generated by multiplying the Sales Price by Quantity
#      - Total Profit: The total profit is earned by multiplying the Profit by Quantity
#      - Discount Price: The amount of discount applied, calculated based on the Original Price and Discount
#      - Total Discount: The total discount value for the quantity sold
# - Create a new column, Shipping Urgency, based on Days to Ship
#      - If Days to Ship is 0, set to "Immediate"
#      - If Days to Ship is between 1 and 3, set to "Urgent"
#      - If Days to Ship is more than 3, set to "Standard"
# - Create a column that calculates days since last order
# - Create a new dataset that stores the total sales, quantity, and discount per customer, and then merge these back to the original dataset

# %%
df['original_price'] = df['sales_price'] / (1 - df['discount'])
df['total_sales'] = df['sales_price'] * df['quantity']
df['total_profit'] = df['profit'] * df['quantity']
df['discount_price'] = df['original_price'] * df['discount']
df['total_discount'] = df['discount_price'] * df['quantity']
print(f'Shape - {df.shape}')
df.head()
# Out:
# Shape - (9993, 27)
#          order_id order_date  ship_date       ship_mode customer_id  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      segment        country             city       state postal_code region  \
# 0   Consumer  United States        Henderson    Kentucky       42420  South
# 1   Consumer  United States        Henderson    Kentucky       42420  South
# 2  Corporate  United States      Los Angeles  California       90036   West
# 3   Consumer  United States  Fort Lauderdale     Florida       33311  South
# 4   Consumer  United States  Fort Lauderdale     Florida       33311  South
#
#         product_id         category sub_category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name  sales_price  quantity  \
# 0                  Bush Somerset Collection Bookcase     261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2
#
#    discount    profit  days_to_ship customer_name_masked  original_price  \
# 0      0.00   41.9136             3                  C G          261.96
# 1      0.00  219.5820             3                  C G          731.94
# 2      0.00    6.8714             4                  D H           14.62
# 3      0.45 -383.0310             7                  S O         1741.05
# 4      0.20    2.5164             7                  S O           27.96
#
#    total_sales  total_profit  discount_price  total_discount shipping_urgency
# 0     523.9200       83.8272          0.0000          0.0000           Urgent
# 1    2195.8200      658.7460          0.0000          0.0000           Urgent
# 2      29.2400       13.7428          0.0000          0.0000         Standard
# 3    4787.8875    -1915.1550        783.4725       3917.3625         Standard
# 4      44.7360        5.0328          5.5920         11.1840         Standard

# %%
df['shipping_urgency'] = df['days_to_ship'].apply(lambda x: "Immediate" if x==0 else "Standard" if x>3 else "Urgent")
print(f'Shape - {df.shape}')
# Out:
# Shape - (9993, 27)

# %%
customer_1st_order_date = df.groupby('customer_id')['order_date'].min()

def subtract_1stOrderDt_from_OrderDt(row):
    return row['order_date'] - customer_1st_order_date[row['customer_id']]

df['days_since_last_order'] = df.apply(subtract_1stOrderDt_from_OrderDt, axis='columns')
df.head(60)
# Out:
#           order_id order_date  ship_date       ship_mode customer_id  \
# 0   CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1   CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2   CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3   US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4   US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5   CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6   CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7   CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8   CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9   CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 12  CA-2017-114412 2017-04-15 2017-04-20  Standard Class    AA-10480
# 13  CA-2016-161389 2016-12-05 2016-12-10  Standard Class    IM-15070
# 14  US-2015-118983 2015-11-22 2015-11-26  Standard Class    HP-14815
# 15  US-2015-118983 2015-11-22 2015-11-26  Standard Class    HP-14815
#
Central  OFF-AP-10002311  Office Supplies   Appliances
# 15  Central  OFF-BI-10000756  Office Supplies      Binders
# 16  Central  OFF-ST-10004186  Office Supplies      Storage
# 17     West  OFF-ST-10000107  Office Supplies      Storage
# 18     West  OFF-AR-10003056  Office Supplies          Art
# 19     West  OFF-BI-10002215  Office Supplies      Binders
# 20  Central  OFF-AR-10000246  Office Supplies          Art
# 21  Central  OFF-AP-10001492  Office Supplies   Appliances
# 22     East  FUR-CH-10002774        Furniture       Chairs
# 23     West  FUR-TA-10000577        Furniture       Tables
# 24     West  OFF-BI-10001634  Office Supplies      Binders
# 25     West  TEC-AC-10003027       Technology  Accessories
# 26     East  FUR-BO-10004834        Furniture    Bookcases
# 27     East  OFF-BI-10000474  Office Supplies      Binders
# 28     East  FUR-FU-10004848        Furniture  Furnishings
# 29     East  OFF-EN-10001509  Office Supplies    Envelopes
# 30     East  OFF-AR-10004042  Office Supplies          Art
# 31     East  OFF-BI-10001525  Office Supplies      Binders
# 32     East  OFF-AR-10001683  Office Supplies          Art
# 33  Central  OFF-PA-10000249  Office Supplies        Paper
# 34  Central  TEC-PH-10004977       Technology       Phones
# 35  Central  FUR-FU-10003664        Furniture  Furnishings
# 36  Central  OFF-EN-10002986  Office Supplies    Envelopes
# 37  Central  FUR-BO-10002545        Furniture    Bookcases
# 38  Central  FUR-CH-10004218        Furniture       Chairs
# 39  Central  TEC-PH-10000486       Technology       Phones
# 40  Central  TEC-PH-10004093       Technology       Phones
# 41     West  OFF-ST-10003479  Office Supplies      Storage
# 42    South  OFF-ST-10003282  Office Supplies      Storage
# 43  Central  TEC-AC-10000171       Technology  Accessories
# 44  Central  OFF-BI-10003291  Office Supplies      Binders
# 45  Central  OFF-ST-10001713  Office Supplies      Storage
# 46     East  TEC-AC-10002167       Technology  Accessories
# 47     East  TEC-PH-10003988       Technology       Phones
# 48  Central  OFF-BI-10004410  Office Supplies      Binders
# 49  Central  OFF-LA-10002762  Office Supplies       Labels
# 50  Central  FUR-FU-10001706        Furniture  Furnishings
# 51  Central  FUR-CH-10003061        Furniture       Chairs
# 52     East  OFF-FA-10000304  Office Supplies    Fasteners
# 53     East  TEC-PH-10002447       Technology       Phones
# 54     East  OFF-ST-10000604  Office Supplies      Storage
# 55     East  OFF-PA-10001569  Office Supplies        Paper
# 56     East  FUR-CH-10003968        Furniture       Chairs
# 57     East  OFF-PA-10000587  Office Supplies        Paper
# 58     East  TEC-AC-10002167       Technology  Accessories
# 59     East  OFF-BI-10001460  Office Supplies      Binders
#
#                                          product_name  sales_price  quantity  \
# 0                   Bush Somerset Collection Bookcase     261.9600         2
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3
# 2   Self-Adhesive Address Labels for Typewriters b...      14.6200         2
# 3       Bretford CR4500 Series Slim Rectangular Table     957.5775         5
# 4                      Eldon Fold 'N Roll Cart System      22.3680         2
# 5   Eldon Expressions Wood and Plastic Desk Access...      48.8600         7
# 6                                          Newell 322       7.2800         4
# 7                      Mitel 5320 IP Phone VoIP phone     907.1520         6
# 8   DXL Angle-View Binders with Locking Rings by S...      18.5040         3
# 9                    Belkin F5C206VTEL 6 Outlet Surge     114.9000         5
# 10           Chromcraft Rectangular Conference Tables    1706.1840         9
# 11      Konftel 250 Conference�phone�- Charcoal black     911.4240         4
# 12                                         Xerox 1967      15.5520         3
# 13        Fellowes PB200 Plastic Comb Binding Machine     407.9760         3
# 14  Holmes Replacement Filter for HEPA Air Cleaner...      68.8100         5
# 15   Storex DuraTech Recycled Plastic Frosted Binders       2.5440         3
# 16  Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x...     665.8800         6
# 17                         Fellowes Super Stor/Drawer      55.5000         2
# 18                                         Newell 341       8.5600         2
# 19        Wilson Jones Hanging View Binder, White, 1"      22.7200         4
# 20                                         Newell 318      19.4600         7
# 21        Acco Six-Outlet Power Strip, 4' Cord Length      60.3400         7
# 22                 Global Deluxe Stacking Chair, Gray      71.3720         2
# 23      Bretford CR4500 Series Slim Rectangular Table    1044.6300         3
# 24                    Wilson Jones Active Use Binders      11.6480         2
# 25   Imation�8GB Mini TravelDrive USB 2.0�Flash Drive      90.5700         3
# 26  Riverside Palais Royal Lawyers Bookcase, Royal...    3083.4300         7
# 27  Avery Recycled Flexi-View Covers for Binding S...       9.6180         2
# 28  Howard Miller 13-3/4" Diameter Brushed Chrome ...     124.2000         3
# 29                          Poly String Tie Envelopes       3.2640         2
# 30  BOSTON Model 1800 Electric Pencil Sharpeners, ...      86.3040         6
# 31  Acco Pressboard Covers with Storage Hooks, 14 ...       6.8580         6
# 32                                     Lumber Crayons      15.7600         2
# 33                                  Easy-staple paper      29.4720         3
# 34                                        GE 30524EE4    1097.5440         7
# 35  Electrix Architect's Clamp-On Swing Arm Lamp, ...     190.9200         5
# 36  #10-4 1/8" x 9 1/2" Premium Diagonal Seam Enve...     113.3280         9
# 37  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...     532.3992         3
# 38           Global Fabric Manager's Chair, Dark Gray     212.0580         3
# 39                    Plantronics HL10 Handset Lifter     371.1680         4
# 40                                 Panasonic Kx-TS550     147.1680         4
# 41   Eldon Base for stackable storage shelf, platinum      77.8800         2
# 42  Advantus 10-Drawer Portable Organizer, Chrome ...      95.6160         2
# 43  Verbatim 25 GB 6x Blu-ray Single Layer Recorda...      45.9800         2
# 44  Wilson Jones Leather-Like Binders with DublLoc...      17.4600         2
# 45  Gould Plastics 9-Pocket Panel Bin, 18-3/8w x 5...     211.9600         4
# 46  Imation�8gb Micro Traveldrive Usb 2.0�Flash Drive      45.0000         3
# 47  LF Elite 3D Dazzle Designer Hard Case Cover, L...      21.8000         2
# 48  C-Line Peel & Stick Add-On Filing Pockets, 8-3...      38.2200         6
# 49                                          Avery 485      75.1800         6
# 50                       Longer-Life Soft White Bulbs       6.1600         2
# 51                   Global Leather Task Chair, Black      89.9900         1
# 52                                 Advantus Push Pins      15.2600         7
# 53                   AT&T CL83451 4-Handset Telephone    1029.9500         5
# 54                    Home/Office Personal File Carts     208.5600         6
# 55                                          Xerox 232      32.4000         5
# 56                           Novimex Turbo Task Chair     319.4100         5
# 57             Array Parchment Paper, Assorted Colors      14.5600         2
# 58  Imation�8gb Micro Traveldrive Usb 2.0�Flash Drive      30.0000         2
# 59                              Plastic Binding Combs      48.4800         4
#
#     discount     profit  days_to_ship customer_name_masked  original_price  \
# 10         Standard                0 days
# 11         Standard                0 days
# 12         Standard             1077 days
# 13         Standard              717 days
# 14         Standard              565 days
# 15         Standard              565 days
# 16         Standard                0 days
# 17           Urgent                0 days
# 18         Standard                0 days
# 19         Standard                0 days
# 20         Standard              980 days
# 21         Standard              980 days
# 22           Urgent             1040 days
# 23         Standard              508 days
# 24         Standard              563 days
# 25         Standard              563 days
# 26         Standard              335 days
# 27         Standard              335 days
# 28         Standard              335 days
# 29         Standard              335 days
# 30         Standard              335 days
# 31         Standard              335 days
# 32         Standard              335 days
# 33         Standard             1168 days
# 34           Urgent              427 days
# 35           Urgent              427 days
# 36         Standard              600 days
# 37         Standard              600 days
# 38         Standard              600 days
# 39         Standard              600 days
# 40         Standard             1298 days
# 41         Standard              831 days
# 42         Standard             1083 days
# 43           Urgent              545 days
# 44           Urgent              545 days
# 45         Standard              211 days
# 46         Standard              671 days
# 47         Standard              671 days
# 48         Standard              470 days
# 49         Standard              470 days
# 50         Standard              470 days
# 51         Standard              470 days
# 52         Standard              839 days
# 53         Standard              839 days
# 54           Urgent                0 days
# 55           Urgent                0 days
# 56           Urgent                0 days
# 57           Urgent                0 days
# 58           Urgent                0 days
# 59           Urgent                0 days

# %% [markdown]
# - Create a new dataset that stores the total sales, quantity, and discount per customer, and then merge these back to the original dataset

# %%
customer_id_grouped = df.groupby('customer_id')
customer_id_grouped.nunique()
# Out:
#              order_id  order_date  ship_date  ship_mode  segment  country  \
# customer_id
# AA-10315            5           5          5          2        1        1
# AA-10375            9           9          9          3        1        1
# AA-10480            4           4          4          2        1        1
# AA-10645            6           6          6          2        1        1
# AB-10015            3           3          3          2        1        1
# ...               ...         ...        ...        ...      ...      ...
# XP-21865           11          11         10          3        1        1
# YC-21895            5           5          5          3        1        1
# YS-21880            8           8          8          2        1        1
# ZC-21910           13          13         13          3        1        1
# ZD-21925            5           5          5          4        1        1
#
#              city  state  postal_code  region  product_id  category  \
# customer_id
# AA-10315        4      4            5       3          11         3
# AA-10375        9      8            9       4          15         3
# AA-10480        4      4            4       3          12         3
# AA-10645        6      5            6       4          18         3
# AB-10015        3      3            3       2           6         3
# ...           ...    ...          ...     ...         ...       ...
# XP-21865       10      8           11       4          28         3
# YC-21895        5      4            5       3           8         3
# YS-21880        8      6            8       3          11         3
# ZC-21910       11     10           13       4          31         3
# ZD-21925        5      4            5       3           9         3
#
#              sub_category  product_name  sales_price  quantity  discount  \
# customer_id
# AA-10315                9            11           11         4         2
# AA-10375                7            15           15         5         2
# AA-10480                7            12           12         5         2
# AA-10645                9            18           18         5         4
# AB-10015                5             6            6         3         2
# ...                   ...           ...          ...       ...       ...
# XP-21865                9            28           28         8         3
# YC-21895                6             8            8         5         2
# YS-21880                8            11           11         6         2
# ZC-21910               12            31           30         8         6
# ZD-21925                6             9            9         4         2
#
#              profit  days_to_ship  customer_name_masked  original_price  \
# customer_id
# AA-10315         11             2                     1              11
# AA-10375         15             4                     1              15
# AA-10480         12             3                     1              12
# AA-10645         18             4                     1              18
# AB-10015          6             3                     1               6
# ...             ...           ...                   ...             ...
# XP-21865         28             5                     1              28
# YC-21895          8             4                     1               8
# YS-21880         11             5                     1              11
# ZC-21910         31             5                     1              30
# ZD-21925          9             5                     1               9
#
#              total_sales  total_profit  discount_price  total_discount  \
# customer_id
# AA-10315              11            11               6               6
# AA-10375              15            15               7               7
# AA-10480              12            12               2               2
# AA-10645              18            18               5               5
# AB-10015               6             6               3               3
# ...                  ...           ...             ...             ...
# XP-21865              28            28               8               8
# YC-21895               8             8               4               4
# YS-21880              11            11               4               4
# ZC-21910              30            31              21              21
# ZD-21925               9             9               6               6
#
#              shipping_urgency  days_since_last_order
# customer_id
# AA-10315                    2                      5
# AA-10375                    2                      9
# AA-10480                    2                      4
# AA-10645                    2                      6
# AB-10015                    2                      3
# ...                       ...                    ...
# XP-21865                    2                     11
# YC-21895                    3                      5
# YS-21880                    2                      8
# ZC-21910                    2                     13
# ZD-21925                    3                      5
#
# [793 rows x 27 columns]

# %%
customer_id_grouped = df.groupby('customer_id')
total_sale_to_customer = customer_id_grouped['total_sales'].sum()
quantity_sold_to_customer = customer_id_grouped['quantity'].sum()
discount_to_customer = customer_id_grouped['total_discount'].sum()

sales_stats_per_customer = pd.DataFrame(data={
    'total_sales': total_sale_to_customer,
    'quantity': quantity_sold_to_customer,
    'total_discount': discount_to_customer
}, index = customer_1st_order_date.index)

# %%
sales_stats_per_customer.to_csv('./SaleStatsCustomerWise.csv')

print(f' shape of dataframe - {sales_stats_per_customer.shape}')
sales_stats_per_customer.head()
# Out:
#  shape of dataframe - (793, 3)
#              total_sales  quantity  total_discount
# customer_id
# AA-10315       16073.344        30        3681.906
# AA-10375        2734.830        41         188.540
# AA-10480        5493.936        36          11.664
# AA-10645       22927.855        64        3342.735
# AB-10015        1984.480        13          18.490

# %%
merged_df = pd.merge(df, sales_stats_per_customer, left_on='customer_id', right_index=True, suffixes=(None, "_to_customer"))
merged_df.head()
# Out:
#          order_id order_date  ship_date       ship_mode customer_id  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      segment        country             city       state postal_code region  \
# 0   Consumer  United States        Henderson    Kentucky       42420  South
# 1   Consumer  United States        Henderson    Kentucky       42420  South
# 2  Corporate  United States      Los Angeles  California       90036   West
# 3   Consumer  United States  Fort Lauderdale     Florida       33311  South
# 4   Consumer  United States  Fort Lauderdale     Florida       33311  South
#
#         product_id         category sub_category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name  sales_price  quantity  \
# 0                  Bush Somerset Collection Bookcase     261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...      14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table     957.5775         5
# 4                     Eldon Fold 'N Roll Cart System      22.3680         2
#
#    discount    profit  days_to_ship customer_name_masked  original_price  \
# 0      0.00   41.9136             3                  C G          261.96
# 1      0.00  219.5820             3                  C G          731.94
# 2      0.00    6.8714             4                  D H           14.62
# 3      0.45 -383.0310             7                  S O         1741.05
# 4      0.20    2.5164             7                  S O           27.96
#
#    total_sales  total_profit  discount_price  total_discount shipping_urgency  \
# 0     523.9200       83.8272          0.0000          0.0000           Urgent
# 1    2195.8200      658.7460          0.0000          0.0000           Urgent
# 2      29.2400       13.7428          0.0000          0.0000         Standard
# 3    4787.8875    -1915.1550        783.4725       3917.3625         Standard
# 4      44.7360        5.0328          5.5920         11.1840         Standard
#
#   days_since_last_order  total_sales_to_customer  quantity_to_customer  \
# 0              390 days                3549.6600                    14
# 1              390 days                3549.6600                    14
# 2                0 days                6156.8940                    28
# 3                0 days               10343.1775                    52
# 4                0 days               10343.1775                    52
#
#    total_discount_to_customer
# 0                   1192.8000
# 1                   1192.8000
# 2                   4212.3260
# 3                   4553.4825
# 4                   4553.4825

# %% [markdown]
# ## 9. Outlier Detection and Handling
# - Identify and handle outliers in the Sales Price column
# - Create a function called remove_outliers that takes as an argument the dataframe and the column that needs to be searched for outliers. Using the 3 * IQR rule, the function should detect and remove the outliers to return the cleaned dataframe
# - Now use the function to detect outliers and remove outliers from the Sales Price and Profit columns

# %%
df.describe().loc[['mean', 'std']]
# Out:
#                          order_date                      ship_date  \
# mean  2016-04-30 08:01:43.752626688  2016-05-04 07:01:29.702792192
# std                             NaN                            NaN
#
#       sales_price  quantity  discount      profit  days_to_ship  \
# mean   229.852846  3.789853  0.156188   28.660971      3.958171
# std    623.276074  2.225136  0.206457  234.271476      1.747654
#
#       original_price  total_sales  total_profit  discount_price  \
# mean      286.553896  1149.555275    143.145687       56.701050
# std       864.138239  3898.856566   1389.024079      360.904715
#
#       total_discount        days_since_last_order
# mean      282.553539  573 days 22:09:02.539777848
# std      2130.512305  422 days 20:18:04.149017112

# %% [markdown]
# - as we can see, the std of `sales_price` is very high wrt its mean. And since most of the other attributes are dependent on sales_price, the others have the same situation as well.
# - we'll use the 3\*IQR to flag outliers as the 1.5\*IQR method would flag most of the data as outliers.

# %%
fig, axs = plt.subplots(1, 2, sharey=True, figsize=(12, 4))
sns.boxplot(data=df, x='sales_price', y='category', ax=axs[0])
sns.boxplot(data=df, x='sales_price', y='category', whis=3, ax=axs[1])
axs[0].set_title("Default Whisker")
axs[1].set_title("Whisker = 3")
plt.show()

# %%
def count_outliers(s, whis=1.5):
    q1, q3 = np.percentile(s, [25, 75])
    iqr = q3 - q1
    low, up = q1 - (iqr*whis), q3 + (iqr*whis)
    count = len(s.loc[(s < low) | (s > up)])
    return count

print(count_outliers(df['sales_price']))
print(count_outliers(df['sales_price'], whis=3))
# Out:
# 1167
# 668

# %%
def remove_outlier(df, col, whis=1.5):
    q1, q3 = np.percentile(df[col], [25, 75])
    iqr = q3 - q1
    low, up = q1 - (iqr*whis), q3 + (iqr*whis)
    df_new = df.loc[(df[col] >= low) & (df[col] <= up)].copy()
    return df_new

print(remove_outlier(df, 'sales_price').shape)
print(remove_outlier(df, 'sales_price', whis=3).shape)
# Out:
# (8826, 28)
# (9325, 28)

# %%
df_wdout_outliers = remove_outlier(df, 'sales_price', whis=3)
fig, axs = plt.subplots(1, 2, sharey=True, figsize=(12, 4))
sns.boxplot(data=df_wdout_outliers, x='sales_price', y='category', ax=axs[0])
sns.boxplot(data=df_wdout_outliers, x='sales_price', y='category', whis=3, ax=axs[1])
axs[0].set_title("Default Whisker")
axs[1].set_title("Whisker = 3")
plt.show()
